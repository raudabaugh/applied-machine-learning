# %%
# %matplotlib inline

# %%
from numpy import genfromtxt
numeric_data = genfromtxt('iris.data.txt', delimiter=',', dtype=None, usecols=(0,1,2,3))
class_data = genfromtxt('iris.data.txt', delimiter=',', dtype=None, usecols=(4))

attribute_dict = {0: "sepal length", 1: "sepal width", 2: "petal length", 3: "petal width"}
colors = {'Iris-setosa': 'r', 'Iris-versicolor': 'g', 'Iris-virginica': 'b'}
colors = [colors[key] for key in class_data]

from itertools import permutations
from matplotlib import pylab as plt

for p in permutations(range(4), 2):
    print attribute_dict[p[1]] + " vs " + attribute_dict[p[0]]
    plt.scatter(numeric_data[:,p[0]], numeric_data[:,p[1]], c=colors)
    plt.show()
# Out:
# sepal width vs sepal length
# petal length vs sepal length
# petal width vs sepal length
# sepal length vs sepal width
# petal length vs sepal width
# petal width vs sepal width
# sepal length vs petal length
# sepal width vs petal length
# petal width vs petal length
# sepal length vs petal width
# sepal width vs petal width
# petal length vs petal width
